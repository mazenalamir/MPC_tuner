# %% [markdown]
# # Example notebook using the package MPC_tuner
#
# This notebook shows the use of the python package MPC_tuner that helps determining admissible NMPC parameters settings given a computation target. The methodology and the package are described in the paper
#
# #### M. Alamir, A Framework and a python-package for real-time N/PC parameters setting   http://arxiv.org/abs/2309.17238. 2023.
#
# (See also the readme file in the git repository).

# %%
import numpy as np
from MPC_tuner import Design_MPC, Sigma, generate_A, OptimPar
from user_defined_pvtol import pvtol

# Generate the set of scenarios
#--------------------------------------------------
# Here, a small number of batch of small size is used for the illustration.
# replace by nb=30, nsb=10 to conform to the paper

nb, nsb = 5, 10  
A = generate_A(pvtol, nb, nsb)

# Generate the set of candidate sigma's
#--------------------------------------------------
# replace by N_trial=100 to conform to the paper 

N_trials = 25   
S = [Sigma() for _ in range(N_trials)]

# Set the Design meta-parameters and run the Design
#--------------------------------------------------
optim_par = OptimPar(gam=0.98, c_max=0.1,
                     dev_acc=1.0, T=0.5)

R_design_log = Design_MPC(pvtol, S, A, optim_par)
# Out:
# -------------
# inspecting config #0 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0.25, 0.5]
# Dichotomy on: [0.25, 0.375]
# Dichotomy on: [0.25, 0.3125]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]]
# ------------------------------------
# -------------
# inspecting config #1 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.5, 0.75]
# Dichotomy on: [0.625, 0.75]
# Dichotomy on: [0.625, 0.6875]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #2 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.5, 0.75]
# Dichotomy on: [0.625, 0.75]
# Dichotomy on: [0.6875, 0.75]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #3 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0.25, 0.5]
# Dichotomy on: [0.25, 0.375]
# Dichotomy on: [0.25, 0.3125]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #4 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0.0625, 0.125]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]]
# ------------------------------------
# -------------
# inspecting config #5 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.5, 0.75]
# Dichotomy on: [0.625, 0.75]
# Dichotomy on: [0.6875, 0.75]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #6 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]]
# ------------------------------------
# -------------
# inspecting config #7 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.5, 0.75]
# Dichotomy on: [0.625, 0.75]
# Dichotomy on: [0.625, 0.6875]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #8 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.5, 0.75]
# Dichotomy on: [0.625, 0.75]
# Dichotomy on: [0.6875, 0.75]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #9 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]]
# ------------------------------------
# -------------
# inspecting config #10 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.5, 0.75]
# Dichotomy on: [0.625, 0.75]
# Dichotomy on: [0.625, 0.6875]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #11 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0.25, 0.5]
# Dichotomy on: [0.375, 0.5]
# Dichotomy on: [0.4375, 0.5]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]]
# ------------------------------------
# -------------
# inspecting config #12 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.75, 1]
# Dichotomy on: [0.75, 0.875]
# Dichotomy on: [0.75, 0.8125]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]]
# ------------------------------------
# -------------
# inspecting config #13 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]]
# ------------------------------------
# -------------
# inspecting config #14 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]]
# ------------------------------------
# -------------
# inspecting config #15 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]]
# ------------------------------------
# -------------
# inspecting config #16 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.5, 0.75]
# Dichotomy on: [0.5, 0.625]
# Dichotomy on: [0.5, 0.5625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]]
# ------------------------------------
# -------------
# inspecting config #17 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.75, 1]
# Dichotomy on: [0.75, 0.875]
# Dichotomy on: [0.75, 0.8125]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #18 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]
#  [1.80000000e+01 0.00000000e+00            inf]]
# ------------------------------------
# -------------
# inspecting config #19 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]
#  [1.80000000e+01 0.00000000e+00            inf]
#  [1.90000000e+01 0.00000000e+00            inf]]
# ------------------------------------
# -------------
# inspecting config #20 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0.25, 0.5]
# Dichotomy on: [0.375, 0.5]
# Dichotomy on: [0.375, 0.4375]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]
#  [1.80000000e+01 0.00000000e+00            inf]
#  [1.90000000e+01 0.00000000e+00            inf]
#  [2.00000000e+01 3.75000000e-01 2.01988511e+02]]
# ------------------------------------
# -------------
# inspecting config #21 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0, 0.25]
# Dichotomy on: [0, 0.125]
# Dichotomy on: [0, 0.0625]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]
#  [1.80000000e+01 0.00000000e+00            inf]
#  [1.90000000e+01 0.00000000e+00            inf]
#  [2.00000000e+01 3.75000000e-01 2.01988511e+02]
#  [2.10000000e+01 0.00000000e+00            inf]]
# ------------------------------------
# -------------
# inspecting config #22 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.75, 1]
# Dichotomy on: [0.75, 0.875]
# Dichotomy on: [0.75, 0.8125]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]
#  [1.80000000e+01 0.00000000e+00            inf]
#  [1.90000000e+01 0.00000000e+00            inf]
#  [2.00000000e+01 3.75000000e-01 2.01988511e+02]
#  [2.10000000e+01 0.00000000e+00            inf]
#  [2.20000000e+01 7.81250000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #23 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0, 0.5]
# Dichotomy on: [0.25, 0.5]
# Dichotomy on: [0.375, 0.5]
# Dichotomy on: [0.4375, 0.5]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]
#  [1.80000000e+01 0.00000000e+00            inf]
#  [1.90000000e+01 0.00000000e+00            inf]
#  [2.00000000e+01 3.75000000e-01 2.01988511e+02]
#  [2.10000000e+01 0.00000000e+00            inf]
#  [2.20000000e+01 7.81250000e-01            inf]
#  [2.30000000e+01 4.37500000e-01            inf]]
# ------------------------------------
# -------------
# inspecting config #24 for the set A[0]
# -------------
# Dichotomy on: [0, 1]
# Dichotomy on: [0.5, 1]
# Dichotomy on: [0.75, 1]
# Dichotomy on: [0.75, 0.875]
# Dichotomy on: [0.8125, 0.875]
# --------- current situation --------
# [[0.00000000e+00 2.50000000e-01 6.17824116e+02]
#  [1.00000000e+00 6.56250000e-01            inf]
#  [2.00000000e+00 6.87500000e-01            inf]
#  [3.00000000e+00 2.81250000e-01            inf]
#  [4.00000000e+00 9.37500000e-02            inf]
#  [5.00000000e+00 6.87500000e-01            inf]
#  [6.00000000e+00 0.00000000e+00            inf]
#  [7.00000000e+00 6.25000000e-01            inf]
#  [8.00000000e+00 7.18750000e-01            inf]
#  [9.00000000e+00 0.00000000e+00            inf]
#  [1.00000000e+01 6.25000000e-01            inf]
#  [1.10000000e+01 4.37500000e-01 1.20528639e+02]
#  [1.20000000e+01 7.81250000e-01 2.51065374e+03]
#  [1.30000000e+01 3.12500000e-02            inf]
#  [1.40000000e+01 3.12500000e-02 1.31665318e+02]
#  [1.50000000e+01 3.12500000e-02            inf]
#  [1.60000000e+01 5.00000000e-01 1.16235064e+02]
#  [1.70000000e+01 7.50000000e-01            inf]
#  [1.80000000e+01 0.00000000e+00            inf]
#  [1.90000000e+01 0.00000000e+00            inf]
#  [2.00000000e+01 3.75000000e-01 2.01988511e+02]
#  [2.10000000e+01 0.00000000e+00            inf]
#  [2.20000000e+01 7.81250000e-01            inf]
#  [2.30000000e+01 4.37500000e-01            inf]
#  [2.40000000e+01 8.43750000e-01            inf]]
# ------------------------------------
# number of removed configuration = 19
# -------------
# inspecting config #0 for the set A[1]
# -------------
# --------- current situation --------
# [[0 None inf]]
# ------------------------------------
# -------------
# inspecting config #11 for the set A[1]
# -------------
# --------- current situation --------
# [[0 None inf]
#  [11 0.4375 131.44717147166324]]
# ------------------------------------
# -------------
# inspecting config #12 for the set A[1]
# -------------
# --------- current situation --------
# [[0 None inf]
#  [11 0.4375 131.44717147166324]
#  [12 0.78125 2162.4826788499076]]
# ------------------------------------
# -------------
# inspecting config #14 for the set A[1]
# -------------
# --------- current situation --------
# [[0 None inf]
#  [11 0.4375 131.44717147166324]
#  [12 0.78125 2162.4826788499076]
#  [14 0.03125 121.30668276394792]]
# ------------------------------------
# -------------
# inspecting config #16 for the set A[1]
# -------------
# --------- current situation --------
# [[0 None inf]
#  [11 0.4375 131.44717147166324]
#  [12 0.78125 2162.4826788499076]
#  [14 0.03125 121.30668276394792]
#  [16 0.5 127.08532261246496]]
# ------------------------------------
# -------------
# inspecting config #20 for the set A[1]
# -------------
# --------- current situation --------
# [[0 None inf]
#  [11 0.4375 131.44717147166324]
#  [12 0.78125 2162.4826788499076]
#  [14 0.03125 121.30668276394792]
#  [16 0.5 127.08532261246496]
#  [20 0.375 inf]]
# ------------------------------------
# number of removed configuration = 21
# -------------
# inspecting config #11 for the set A[2]
# -------------
# --------- current situation --------
# [[ 11.           0.4375     136.97662602]]
# ------------------------------------
# -------------
# inspecting config #12 for the set A[2]
# -------------
# --------- current situation --------
# [[1.10000000e+01 4.37500000e-01 1.36976626e+02]
#  [1.20000000e+01 7.81250000e-01 2.61227241e+03]]
# ------------------------------------
# -------------
# inspecting config #14 for the set A[2]
# -------------
# --------- current situation --------
# [[11 0.4375 136.97662601992266]
#  [12 0.78125 2612.2724085477025]
#  [14 None inf]]
# ------------------------------------
# -------------
# inspecting config #16 for the set A[2]
# -------------
# --------- current situation --------
# [[11 0.4375 136.97662601992266]
#  [12 0.78125 2612.2724085477025]
#  [14 None inf]
#  [16 0.5 100.22979959150783]]
# ------------------------------------
# number of removed configuration = 22
# -------------
# inspecting config #11 for the set A[3]
# -------------
# --------- current situation --------
# [[ 11.           0.4375     142.46112842]]
# ------------------------------------
# -------------
# inspecting config #12 for the set A[3]
# -------------
# --------- current situation --------
# [[1.10000000e+01 4.37500000e-01 1.42461128e+02]
#  [1.20000000e+01 7.81250000e-01 2.84527062e+03]]
# ------------------------------------
# -------------
# inspecting config #16 for the set A[3]
# -------------
# --------- current situation --------
# [[1.10000000e+01 4.37500000e-01 1.42461128e+02]
#  [1.20000000e+01 7.81250000e-01 2.84527062e+03]
#  [1.60000000e+01 5.00000000e-01 1.15617356e+02]]
# ------------------------------------
# number of removed configuration = 22
# -------------
# inspecting config #11 for the set A[4]
# -------------
# --------- current situation --------
# [[ 11.           0.4375     122.31915819]]
# ------------------------------------
# -------------
# inspecting config #12 for the set A[4]
# -------------
# --------- current situation --------
# [[1.10000000e+01 4.37500000e-01 1.22319158e+02]
#  [1.20000000e+01 7.81250000e-01 2.15849584e+03]]
# ------------------------------------
# -------------
# inspecting config #16 for the set A[4]
# -------------
# --------- current situation --------
# [[1.10000000e+01 4.37500000e-01 1.22319158e+02]
#  [1.20000000e+01 7.81250000e-01 2.15849584e+03]
#  [1.60000000e+01 5.00000000e-01 9.58300160e+01]]
# ------------------------------------
# number of removed configuration = 22

# %%
R_design_log.df
# Out:
#     kappa  N_pred  n_steps  n_ctr      rho_cstr   rho_final   tau  tau_u  \
# 11      9       6        8      4  8.133070e+06    8.005414  0.02   0.18
# 12      2       7        2      2  9.729466e+06  477.360321  0.02   0.04
# 16      2       5        2      6  8.909096e+06    2.951172  0.02   0.04
#
#     max_iter          cost    alpha
# 11        11    653.732723  0.43750
# 12        12  12289.175285  0.78125
# 16         5    554.997559  0.50000

# %%
import pandas as pd
pd.DataFrame(R_design_log.n_excluded, 
             columns=['Number of excluded congiguration at batch number'], 
             index=[f'Batch #{i+1}' for i in range(len(R_design_log.n_excluded))])
# Out:
#           Number of excluded congiguration at batch number
# Batch #1                                                19
# Batch #2                                                21
# Batch #3                                                22
# Batch #4                                                22
# Batch #5                                                22
